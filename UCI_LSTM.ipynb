# %%
import os
os.chdir("D:/Masters/MachineLearning/Project/Human-activity-Recoginition")

# %%
# !python main.py configs\UCI_LSTM.json
# Out:
#  THE Configuration of your experiment ..
# {'PCA_applied': False,
#  'agent': 'UCI_Agent',
#  'batch_size': 512,
#  'callbacks': {'checkpoint_mode': 'max',
#                'checkpoint_monitor': 'val_acc',
#                'checkpoint_save_best_only': True,
#                'checkpoint_save_weights_only': True,
#                'checkpoint_verbose': True,
#                'tensorboard_write_graph': True},
#  'classes_num': 6,
#  'data_loader': 'UCIDataLoader',
#  'exp_name': 'UC_LSTM',
#  'input_features': 561,
#  'learning_rate': 0.001,
#  'max_epoch': 200,
#  'mode': 'train',
#  'model': 'LSTM',
#  'num_workers': 4,
#  'optimizer': 'Adam',
#  'seed': 1337,
#  'use_scheduler': False,
#  'verbose_training': 1}
#  ***************************************
# The experiment name is UC_LSTM
#  ***************************************
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
